# %% [markdown]
# # Libraries :

# %%
import nltk
import json

from nltk.stem import WordNetLemmatizer

import pickle
import random
import numpy as np

from keras.models import Sequential
import nltk
import json

from nltk.stem import WordNetLemmatizer

import pickle
import random
import numpy as np

from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD

from keras.models import load_model

lemmatizer = WordNetLemmatizer()
ignore = ['!','?']

# %% [markdown]
# # Implementation

# %%
file = open("C:/data.json").read()
data = json.loads(file)

words_Repository=[]
corpus=[]
classes=[]

##lemmatizer = WordNetLemmatizer()
##ignore = ['!','?']

for record in data['info']:
    for request in record['requests']:
        word= nltk.word_tokenize(request)
        word= [lemmatizer.lemmatize(w.lower()) for w in word if w not in ignore]
        words_Repository.extend(word)
        t = record['title']
        corpus.append((word,t))
        if t not in classes:
            classes.append(t)

# %%
words= list(set(words_Repository))

words=sorted(words)

classes=sorted(classes)

pickle.dump(words,open('C:/chatbot/words.pkl','wb'))
pickle.dump(classes,open('C:/chatbot/classes.pkl','wb'))
pickle.dump(corpus,open('C:/chatbot/corpus.pkl','wb'))

# %%
## load data 

words= pickle.load(open('C:/chatbot/words.pkl','rb'))
classes= pickle.load(open('C:/chatbot/classes.pkl','rb'))
corpus= pickle.load(open('C:/chatbot/corpus.pkl','rb'))
model = load_model('C:/chatbot/model.h5')

# %% [markdown]
# # Digital Representation:

# %%
dataSet=[]

for request,class_r in corpus:
    input_vec = [0]*len(words)
    output_vec = [0]*len(classes)
    
    for w in request:
        input_vec[words.index(w)]=1
    
    output_vec[classes.index(class_r)]=1
    
    dataSet.append([input_vec,output_vec])

random.shuffle(dataSet)
dataSet= np.array(dataSet,dtype=object)

x=list(dataSet[:,0])
y=list(dataSet[:,1])

# %% [markdown]
# # Build Model

# %%
def createModel(input_size,output_size):
    model = Sequential()
    model.add(Dense(128,input_shape=(input_size,),activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(output_size,activation='softmax'))
    
    return model

model = createModel(len(words),len(classes))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               11392
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 9)                 585
#
# =================================================================
# Total params: 20,233
# Trainable params: 20,233
# Non-trainable params: 0
# _________________________________________________________________

# %%
### train the model

sgd = SGD(learning_rate=0.01,momentum=0.8,nesterov=True)
model.compile(optimizer=sgd,loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(np.array(x),np.array(y), epochs=200, batch_size=3,verbose=1)
# Out:
# Epoch 1/200
# 16/16 [==============================] - 1s 7ms/step - loss: 2.2203 - accuracy: 0.0851
# Epoch 2/200
# 16/16 [==============================] - 0s 3ms/step - loss: 2.1360 - accuracy: 0.1277
# Epoch 3/200
# 16/16 [==============================] - 0s 3ms/step - loss: 2.1373 - accuracy: 0.1277
# Epoch 4/200
# 16/16 [==============================] - 0s 3ms/step - loss: 1.9699 - accuracy: 0.4468
# Epoch 5/200
# 16/16 [==============================] - 0s 5ms/step - loss: 1.9056 - accuracy: 0.4043
# Epoch 6/200
# 16/16 [==============================] - 0s 3ms/step - loss: 1.8586 - accuracy: 0.4255
# Epoch 7/200
# 16/16 [==============================] - 0s 3ms/step - loss: 1.6627 - accuracy: 0.5745
# Epoch 8/200
# 16/16 [==============================] - 0s 3ms/step - loss: 1.5715 - accuracy: 0.6383
# Epoch 9/200
# 16/16 [==============================] - 0s 3ms/step - loss: 1.5014 - accuracy: 0.5106
# Epoch 10/200
# 16/16 [==============================] - 0s 3ms/step - loss: 1.4061 - accuracy: 0.6596
# Epoch 11/200
# 16/16 [==============================] - 0s 3ms/step - loss: 1.3385 - accuracy: 0.6170
# Epoch 12/200
# 16/16 [==============================] - 0s 3ms/step - loss: 1.2374 - accuracy: 0.6383
# Epoch 13/200
# 16/16 [==============================] - 0s 3ms/step - loss: 1.0331 - accuracy: 0.7447
# Epoch 14/200
# 16/16 [==============================] - 0s 4ms/step - loss: 1.0415 - accuracy: 0.7660
# Epoch 15/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.8224 - accuracy: 0.8936
# Epoch 16/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.8187 - accuracy: 0.8936
# Epoch 17/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6565 - accuracy: 0.8936
# Epoch 18/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.7287 - accuracy: 0.7660
# Epoch 19/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6349 - accuracy: 0.8936
# Epoch 20/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6949 - accuracy: 0.7234
# Epoch 21/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4613 - accuracy: 0.8936
# Epoch 22/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5532 - accuracy: 0.8723
# Epoch 23/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5223 - accuracy: 0.8085
# Epoch 24/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4214 - accuracy: 0.9149
# Epoch 25/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5808 - accuracy: 0.8085
# Epoch 26/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3085 - accuracy: 0.9574
# Epoch 27/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4688 - accuracy: 0.7872
# Epoch 28/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4363 - accuracy: 0.8511
# Epoch 29/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2435 - accuracy: 0.9574
# Epoch 30/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3791 - accuracy: 0.8936
# Epoch 31/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2762 - accuracy: 0.9787
# Epoch 32/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2072 - accuracy: 0.9574
# Epoch 33/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1559 - accuracy: 1.0000
# Epoch 34/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1686 - accuracy: 0.9574
# Epoch 35/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2413 - accuracy: 0.9149
# Epoch 36/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2361 - accuracy: 0.9149
# Epoch 37/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1318 - accuracy: 0.9787
# Epoch 38/200
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2052 - accuracy: 0.9574
# Epoch 39/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1983 - accuracy: 0.9787
# Epoch 40/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1998 - accuracy: 0.9362
# Epoch 41/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1175 - accuracy: 1.0000
# Epoch 42/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2044 - accuracy: 0.9574
# Epoch 43/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1855 - accuracy: 0.9787
# Epoch 44/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1200 - accuracy: 0.9787
# Epoch 45/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2647 - accuracy: 0.9362
# Epoch 46/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1610 - accuracy: 0.9574
# Epoch 47/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1721 - accuracy: 0.9574
# Epoch 48/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1156 - accuracy: 1.0000
# Epoch 49/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1387 - accuracy: 0.9787
# Epoch 50/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1110 - accuracy: 0.9787
# Epoch 51/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1993 - accuracy: 0.9362
# Epoch 52/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0749 - accuracy: 0.9787
# Epoch 53/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1703 - accuracy: 0.9362
# Epoch 54/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1192 - accuracy: 0.9787
# Epoch 55/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1164 - accuracy: 0.9787
# Epoch 56/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1568 - accuracy: 0.9787
# Epoch 57/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0749 - accuracy: 0.9787
# Epoch 58/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0843 - accuracy: 0.9787
# Epoch 59/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0393 - accuracy: 1.0000
# Epoch 60/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1118 - accuracy: 0.9787
# Epoch 61/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1178 - accuracy: 0.9574
# Epoch 62/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0699 - accuracy: 1.0000
# Epoch 63/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1218 - accuracy: 0.9787
# Epoch 64/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0549 - accuracy: 1.0000
# Epoch 65/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0822 - accuracy: 1.0000
# Epoch 66/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0731 - accuracy: 0.9574
# Epoch 67/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1009 - accuracy: 1.0000
# Epoch 68/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0430 - accuracy: 1.0000
# Epoch 69/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1733 - accuracy: 0.9574
# Epoch 70/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0493 - accuracy: 1.0000
# Epoch 71/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0686 - accuracy: 0.9787
# Epoch 72/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0587 - accuracy: 1.0000
# Epoch 73/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0629 - accuracy: 0.9787
# Epoch 74/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0512 - accuracy: 1.0000
# Epoch 75/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1144 - accuracy: 0.9787
# Epoch 76/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0649 - accuracy: 0.9787
# Epoch 77/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0896 - accuracy: 0.9787
# Epoch 78/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0708 - accuracy: 1.0000
# Epoch 79/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0953 - accuracy: 0.9787
# Epoch 80/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0540 - accuracy: 1.0000
# Epoch 81/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0549 - accuracy: 1.0000
# Epoch 82/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0634 - accuracy: 1.0000
# Epoch 83/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0368 - accuracy: 1.0000
# Epoch 84/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1087 - accuracy: 0.9574
# Epoch 85/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 86/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0299 - accuracy: 1.0000
# Epoch 87/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0314 - accuracy: 1.0000
# Epoch 88/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 89/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0460 - accuracy: 1.0000
# Epoch 90/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0790 - accuracy: 0.9787
# Epoch 91/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0637 - accuracy: 1.0000
# Epoch 92/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0781 - accuracy: 0.9787
# Epoch 93/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0691 - accuracy: 0.9787
# Epoch 94/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 95/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0505 - accuracy: 1.0000
# Epoch 96/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0906 - accuracy: 0.9787
# Epoch 97/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0549 - accuracy: 1.0000
# Epoch 98/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0705 - accuracy: 1.0000
# Epoch 99/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 100/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 101/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0272 - accuracy: 0.9787
# Epoch 102/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 103/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 104/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0583 - accuracy: 0.9787
# Epoch 105/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0417 - accuracy: 1.0000
# Epoch 106/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0564 - accuracy: 0.9787
# Epoch 107/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0282 - accuracy: 1.0000
# Epoch 108/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0334 - accuracy: 1.0000
# Epoch 109/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1098 - accuracy: 0.9574
# Epoch 110/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0769 - accuracy: 0.9787
# Epoch 111/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 112/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1366 - accuracy: 0.9574
# Epoch 113/200
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0266 - accuracy: 1.0000
# Epoch 114/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0431 - accuracy: 1.0000
# Epoch 115/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 116/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 117/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0374 - accuracy: 1.0000
# Epoch 118/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0677 - accuracy: 0.9787
# Epoch 119/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 120/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0354 - accuracy: 1.0000
# Epoch 121/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0439 - accuracy: 1.0000
# Epoch 122/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0450 - accuracy: 0.9787
# Epoch 123/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 124/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0364 - accuracy: 0.9787
# Epoch 125/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 0.9787
# Epoch 126/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0409 - accuracy: 0.9787
# Epoch 127/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0352 - accuracy: 1.0000
# Epoch 128/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 129/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0620 - accuracy: 0.9574
# Epoch 130/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0340 - accuracy: 1.0000
# Epoch 131/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0602 - accuracy: 0.9787
# Epoch 132/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0448 - accuracy: 0.9787
# Epoch 133/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0447 - accuracy: 1.0000
# Epoch 134/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 135/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0381 - accuracy: 0.9787
# Epoch 136/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 137/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 138/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 139/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0465 - accuracy: 0.9787
# Epoch 140/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0533 - accuracy: 1.0000
# Epoch 141/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0472 - accuracy: 0.9787
# Epoch 142/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 143/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0646 - accuracy: 0.9787
# Epoch 144/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 145/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0482 - accuracy: 0.9787
# Epoch 146/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0281 - accuracy: 0.9787
# Epoch 147/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0478 - accuracy: 0.9787
# Epoch 148/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0384 - accuracy: 1.0000
# Epoch 149/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 150/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0468 - accuracy: 0.9787
# Epoch 151/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0306 - accuracy: 1.0000
# Epoch 152/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 153/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0478 - accuracy: 1.0000
# Epoch 154/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 155/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 156/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 157/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 158/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0812 - accuracy: 0.9787
# Epoch 159/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0438 - accuracy: 1.0000
# Epoch 160/200
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0438 - accuracy: 1.0000
# Epoch 161/200
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0265 - accuracy: 1.0000
# Epoch 162/200
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 163/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 164/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 165/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0484 - accuracy: 1.0000
# Epoch 166/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0467 - accuracy: 0.9787
# Epoch 167/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0527 - accuracy: 0.9787
# Epoch 168/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 169/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 170/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 171/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 172/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0359 - accuracy: 1.0000
# Epoch 173/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 174/200
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0305 - accuracy: 0.9787
# Epoch 175/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 176/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 177/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 178/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 179/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0298 - accuracy: 0.9787
# Epoch 180/200
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0472 - accuracy: 0.9787
# Epoch 181/200
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 182/200
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0253 - accuracy: 1.0000
# Epoch 183/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 184/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0439 - accuracy: 0.9787
# Epoch 185/200
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 186/200
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 187/200
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 188/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0691 - accuracy: 0.9787
# Epoch 189/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 190/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 191/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 192/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0374 - accuracy: 0.9787
# Epoch 193/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 194/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 195/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 196/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0278 - accuracy: 0.9787
# Epoch 197/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 198/200
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0412 - accuracy: 1.0000
# Epoch 199/200
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0937 - accuracy: 0.9787
# Epoch 200/200
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0421 - accuracy: 0.9787

# %%
model.save('C:/chatbot/model.h5')

# %%
### preprocessing methods

##sen = "hello, how are you?"

def senWords(sen):
    swords=nltk.word_tokenize(sen)
    swords=[lemmatizer.lemmatize(w.lower())for w in swords if w not in ignore]
    return swords

def digitize(sen,words):
    input_vec = [0] * len(words)
    swords = senWords(sen)
    
    for sw in swords:
        if sw in words:
            indx = words.index(sw)
            input_vec[indx] = 1
    return input_vec

def predictClass(sen,words,model):
    sample = digitize(sen,words)
    value = model.predict(np.array([sample]))[0]

    indx = list(value).index(max(value))
    return classes[indx]

def getResponse(sen,words,classes,model):
    tag = predictClass(sen,words,model)
    for record in data['info']:
        if record['title'] == tag :
            return random.choice(record['responses'])

# %% [markdown]
# # GUI Python Tkinter

# %%
from tkinter import *

gui = Tk()

## configuration:
gui.title('ChatBot version -1-')
gui.geometry('400x500')
gui.resizable(width=False,height=False)

##Components:
chatArea = Text(gui,font='Arial')
chatArea.config(state=DISABLED)

scrollBar = Scrollbar(gui,command = chatArea.yview)

def chatting():
    sen=entryBox.get('1.0',END).strip()
    entryBox.delete('1.0',END)
    
    if sen !='':
        ##if sen in qQuestions:
            chatArea.config(state=NORMAL)
            chatArea.insert(END,"You: "+sen+ "\n\n")
        
            res=getResponse(sen,words,classes,model)
        
            chatArea.insert(END,"Bot :"+res+ "\n\n")
        
            chatArea.config(state=DISABLED)
            chatArea.yview(END)
        

f=('Arial',18,'bold')
chatButton = Button(gui,bd=0,command=chatting,width=7,text='send',fg='white',font=f,bg='darkorange',activebackground='gray')

entryBox = Text(gui,font='Arial')

##location
chatArea.place(x=6,y=6,height=380,width=380)
scrollBar.place(x=380,y=6,height=380,width=20)
chatButton.place(x=6,y=400,height=90)
entryBox.place(x=110,y=400,height=90,width=280)
gui.mainloop()
# Out:
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 76ms/step

# %%
# Out:
# ['adverse_drug',
#  'blood_pressure',
#  'blood_pressure_search',
#  'goodbye',
#  'greeting',
#  'hospital_search',
#  'options',
#  'pharmacy_search',
#  'thanks']
